# %%
# Install necessary libraries
import sys
libraries = ["polars", "openai", "instructor", "pydantic"]

for library in libraries:
    try:
        __import__(library)
        print(f"{library} is already installed.")
    except ImportError:
        print(f"{library} not found, installing...")
        # !{sys.executable} -m pip install {library}
# Out:
# polars is already installed.
# openai is already installed.
# instructor is already installed.
# pydantic is already installed.

# %%
import pandas as pd
from utils_iaa import prepare_df
import polars as pl
from llm_utils import annotate_synesthesia

# %% [markdown]
# # Linguistic Synesthesia - yes or no?: Annotating with LLM

# %% [markdown]
# ## Reading and preparing the files

# %%
#reading the file
filepath = "./data/synesthesia-yes-no.csv"
df = pd.read_csv(filepath, sep=",")

# %%
df
# Out:
#              Timestamp A dull head among windy spaces.  \
# 0  06/05/2024 21:57:50                             yes
# 1  07/05/2024 09:24:15                             yes
# 2  08/05/2024 10:02:43                             yes
#
#   A fine, pedantic sunshine in a satin vest  \
# 0                                       yes
# 1                                       yes
# 2                                       yes
#
#   A lonely cab-horse steams and stamps.  \
# 0                                    no
# 1                                   yes
# 2                                   yes
#
#   A silence suffuses the story, and a softness the teller’s eye  \
# 0                                                yes
# 1                                                yes
# 2                                                yes
#
#   And sore must be the storm  \
# 0                        yes
# 1                        yes
# 2                        yes
#
#   Anecdotes of air in dungeons have sometimes proved deadly sweet!  \
# 0                                                yes
# 1                                                yes
# 2                                                 no
#
#   Ascending from the damp savannas But just to hear the grace depart  \
# 0                               no                               yes
# 1                              yes                               yes
# 2                              yes                                no
#
#   But through the water pale and thin Still shine the unoffending feet  ...  \
# 0                                                yes                    ...
# 1                                                yes                    ...
# 2                                                yes                    ...
#
#   the floors of silent seas. the perfumed tincture of the roses  \
# 0                        yes                                 no
# 1                        yes                                yes
# 2                        yes                                yes
#
#   the sessions of sweet silent thought  \
# 0                                  yes
# 1                                  yes
# 2                                  yes
#
#   the wide world and all her fading sweets their substance still lives sweet  \
# 0                                      yes                               yes
# 1                                      yes                               yes
# 2                                      yes                               yes
#
#   through heavy sleep on sightless eyes doth stay  \
# 0                                              no
# 1                                             yes
# 2                                              no
#
#   thy hungry eyes, even till they wink with fulness  \
# 0                                               yes
# 1                                               yes
# 2                                                no
#
#   to hear with eyes belongs to love’s fine wit  \
# 0                                          yes
# 1                                          yes
# 2                                          yes
#
#   what strained touches rhetoric can lend  \
# 0                                     yes
# 1                                      no
# 2                                      no
#
#   your sweet semblance to some other give
# 0                                     yes
# 1                                     yes
# 2                                     yes
#
# [3 rows x 91 columns]

# %%
df = prepare_df(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instance    90 non-null     object
#  1   annotator1  90 non-null     object
#  2   annotator2  90 non-null     object
#  3   annotator3  90 non-null     object
# dtypes: object(4)
# memory usage: 2.9+ KB

# %% [markdown]
# ## Annotating with LLM

# %%
#making a new df with polars for sake of mimicking Enrica's notebook
data = pl.DataFrame(df)

# %%
# Adding a placeholder column for the annotation
data = data.with_columns(pl.Series("annotator-llm", range(0, data.height)))
print(data)
# Out:
# shape: (90, 5)
# ┌─────────────────────────────────┬────────────┬────────────┬────────────┬───────────────┐
# │ instance                        ┆ annotator1 ┆ annotator2 ┆ annotator3 ┆ annotator-llm │
# │ ---                             ┆ ---        ┆ ---        ┆ ---        ┆ ---           │
# │ str                             ┆ str        ┆ str        ┆ str        ┆ i64           │
# ╞═════════════════════════════════╪════════════╪════════════╪════════════╪═══════════════╡
# │ A dull head among windy spaces… ┆ yes        ┆ yes        ┆ yes        ┆ 0             │
# │ A fine, pedantic sunshine in a… ┆ yes        ┆ yes        ┆ yes        ┆ 1             │
# │ A lonely cab-horse steams and … ┆ no         ┆ yes        ┆ yes        ┆ 2             │
# │ A silence suffuses the story, … ┆ yes        ┆ yes        ┆ yes        ┆ 3             │
# │ And sore must be the storm      ┆ yes        ┆ yes        ┆ yes        ┆ 4             │
# │ …                               ┆ …          ┆ …          ┆ …          ┆ …             │
# │ through heavy sleep on sightle… ┆ no         ┆ yes        ┆ no         ┆ 85            │
# │ thy hungry eyes, even till the… ┆ yes        ┆ yes        ┆ no         ┆ 86            │
# │ to hear with eyes belongs to l… ┆ yes        ┆ yes        ┆ yes        ┆ 87            │
# │ what strained touches rhetoric… ┆ yes        ┆ no         ┆ no         ┆ 88            │
# │ your sweet semblance to some o… ┆ yes        ┆ yes        ┆ yes        ┆ 89            │
# └─────────────────────────────────┴────────────┴────────────┴────────────┴───────────────┘

# %%
my_instructions =  """Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains. 
In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain. 
For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.

Do you idenfity lingustic synesthesia in the following text?"""

# %%
annotation_dict = annotate_synesthesia(data, my_instructions)
# Out:
#  --- I HAVE ANNOTATED TEXT 0 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? A dull head among windy spaces.
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 1 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? A fine, pedantic sunshine in a satin vest
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 2 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? A lonely cab-horse steams and stamps.
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 3 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? A silence suffuses the story, and a softness the teller’s eye
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 4 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? And sore must be the storm
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 5 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Anecdotes of air in dungeons have sometimes proved deadly sweet!
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 6 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Ascending from the damp savannas
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 7 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? But just to hear the grace depart
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 8 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? But through the water pale and thin Still shine the unoffending feet
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 9 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Cherries suit robins
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 10 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Crackling with fever
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 11 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Dare you see a soul at the white heat?
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 12 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Defunctive music under sea
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 13 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Demur,--you’re straightway dangerous, and handled with a chain
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 14 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Every street lamp that I pass Beats like a fatalistic drum
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 15 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Except when a street piano, mechanical and tired
# Reiterates some worn-out common song
# With the smell of hyacinths across the garden
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 16 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Faced by the snarled and yelping seas.
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 17 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? Gull against the wind, in the windy straits Of Belle Isle
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 18 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 76 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? sometime too hot the eye of heaven shines
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 77 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? sweet flattery
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 78 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? sweet love, renew thy force
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 79 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? that sweet odour
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 80 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? the floors of silent seas.
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 81 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? the perfumed tincture of the roses
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 82 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? the sessions of sweet silent thought
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 83 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? the wide world and all her fading sweets
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 84 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? their substance still lives sweet
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 85 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? through heavy sleep on sightless eyes doth stay
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 86 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? thy hungry eyes, even till they wink with fulness
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 87 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? to hear with eyes belongs to love’s fine wit
# option='yes'
#
#
#  --- I HAVE ANNOTATED TEXT 88 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? what strained touches rhetoric can lend
# option='no'
#
#
#  --- I HAVE ANNOTATED TEXT 89 ---
# Linguistic synaesthesia involves conceptual conflicts created by two concepts from two distinct sensory domains.
# In most cases, linguistic synaesthesia is realized when a sensory lexeme from one sensory domain describes another sensory lexeme from a different sensory domain.
# For example, in a phrase sweet voice, sweet is a concept originated in TASTE while voice is a HEARING concept. (Zhong and Ahrens, 2021)
# Here we aim to identify the whether instances selected from poetry from different time periods contain synesthesia or not.
#
# Do you idenfity lingustic synesthesia in the following text? your sweet semblance to some other give
# option='yes'

# %%
# Put the annotation in the dataframe and save
data = data.with_columns(pl.col("annotator-llm").replace(annotation_dict))
data.write_csv("./data/final_synesthesia-yes-no_all-annotators.csv")
print(data)
# Out:
# shape: (90, 5)
# ┌─────────────────────────────────┬────────────┬────────────┬────────────┬───────────────┐
# │ instance                        ┆ annotator1 ┆ annotator2 ┆ annotator3 ┆ annotator-llm │
# │ ---                             ┆ ---        ┆ ---        ┆ ---        ┆ ---           │
# │ str                             ┆ str        ┆ str        ┆ str        ┆ str           │
# ╞═════════════════════════════════╪════════════╪════════════╪════════════╪═══════════════╡
# │ A dull head among windy spaces… ┆ yes        ┆ yes        ┆ yes        ┆ no            │
# │ A fine, pedantic sunshine in a… ┆ yes        ┆ yes        ┆ yes        ┆ no            │
# │ A lonely cab-horse steams and … ┆ no         ┆ yes        ┆ yes        ┆ yes           │
# │ A silence suffuses the story, … ┆ yes        ┆ yes        ┆ yes        ┆ yes           │
# │ And sore must be the storm      ┆ yes        ┆ yes        ┆ yes        ┆ no            │
# │ …                               ┆ …          ┆ …          ┆ …          ┆ …             │
# │ through heavy sleep on sightle… ┆ no         ┆ yes        ┆ no         ┆ yes           │
# │ thy hungry eyes, even till the… ┆ yes        ┆ yes        ┆ no         ┆ yes           │
# │ to hear with eyes belongs to l… ┆ yes        ┆ yes        ┆ yes        ┆ yes           │
# │ what strained touches rhetoric… ┆ yes        ┆ no         ┆ no         ┆ no            │
# │ your sweet semblance to some o… ┆ yes        ┆ yes        ┆ yes        ┆ yes           │
# └─────────────────────────────────┴────────────┴────────────┴────────────┴───────────────┘
